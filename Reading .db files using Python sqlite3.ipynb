# %%
import sqlite3
import time
import datetime
import random

conn = sqlite3.connect('D:/Downloads/Udacity.db')
c = conn.cursor()

def create_table():
    c.execute("CREATE TABLE IF NOT EXISTS Tableeg(unix REAL, datestamp TEXT, keyword TEXT, value REAL)")


def data_entry():
    c.execute("INSERT INTO Tableeg VALUES(1452549219,'2016-01-11 13:53:39','Python',6)")
    
    conn.commit()
    c.close()
    conn.close()

def dynamic_data_entry():

    unix = int(time.time())
    date = str(datetime.datetime.fromtimestamp(unix).strftime('%Y-%m-%d %H:%M:%S'))
    keyword = 'Python'
    value = random.randrange(0,10)

    c.execute("INSERT INTO Tableeg (unix, datestamp, keyword, value) VALUES (?, ?, ?, ?)",
          (unix, date, keyword, value))

    conn.commit()
    
#create_table()
#data_entry()

# for i in range(10):
#     dynamic_data_entry()
#     time.sleep(1)
    
def read_from_db():
    c.execute('SELECT * FROM Udacity')
    data = c.fetchall()
    print(data)
    for row in data:
        print(row)
        print("\n")
read_from_db()
c.close
conn.close()
# Out:
# [(1, 'Applying Data Science to Product Management', ' School of Business ', 'intermediate', 'https://d20vrrgs8k4bvw.cloudfront.net/images/degrees/nd030/catalog+image+nd030-1.jpg);', 'https://www.udacity.com/course/applying-data-science-to-product-management--nd030-1'), (2, 'Data Product Manager', ' School of Business ', 'intermediate', 'https://d20vrrgs8k4bvw.cloudfront.net/images/degrees/nd030/catalog+image+nd030.jpg);', 'https://www.udacity.com/course/data-product-manager-nanodegree--nd030'), (3, 'SQL', ' School of Business ', 'beginner', 'https://d20vrrgs8k4bvw.cloudfront.net/images/degrees/nd072/catalog+image+nd072.jpg);', 'https://www.udacity.com/course/learn-sql--nd072'), (4, 'Activation and Retention Strategy', ' School of Business ', 'intermediate', 'https://d20vrrgs8k4bvw.cloudfront.net/images/degrees/nd037/catalog+image+nd037-2.jpg);', 'https://www.udacity.com/course/activation-and-retention-strategy--nd037-2'), (5, 'AI for Healthcare', ' School of Artificial Intelligence '
# ...
